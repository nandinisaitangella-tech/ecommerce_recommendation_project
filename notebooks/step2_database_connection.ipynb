# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="ecommerce_db",
    user="postgres",
    password="N@ndini2005"
)

print("Connection successful!")
conn.close()
# Out:
# Connection successful!
